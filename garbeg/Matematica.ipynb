# %%
# aliquote.org
# https://aliquote.org/writings/
#

$Version
# Out:
# 13.3.0 for Mac OS X x86 (64-bit) (June 12, 2023)

# %%
Plot3D[Sin[x y], {x, -Pi,Pi}, {y, -Pi,Pi}]
# Out:
# -Graphics3D-

# %%
1/0
# Out:
#                                  1
# Power::infy: Infinite expression - encountered.
#                                  0
# ComplexInfinity

# %%
PDF[NegativeBinomialDistribution[2, r]][n]
# Out:
#                            n  2
# Piecewise[{{(1 + n) (1 - r)  r , n >= 0}}]

# %%
Solve[{2x+3y==1, 3x+5y==8},{x,y}]
# Out:
# {{x -> -19, y -> 13}}

# %%
Histogram[RandomVariate[NormalDistribution[0,1], 200]]
# Out:
# -Graphics-

# %%
RandomInteger[100]
# Out:
# 74

# %%
ListPlot[Join[{1,2,3,3,4,6,7,9,19},Reverse[{1,2,3,3,4,6,7,9,19}]]]
# Out:
# -Graphics-
